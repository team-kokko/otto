# %% [markdown]
# #まとめ
#
# * train (最初の 3 週間)
# * valid A（第4週の前半）
# * valid B（第4週の後半）
# * all train (train + validA + validB)
# * test (第5週の前半)
# * LB (第5週の後半)

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# #config

# %%
class CFG:
  VER = 'baseline_ver14'
  #types = 'clicks'

# %%
import numpy as np
import pandas as pd

import collections
from collections import Counter

import lightgbm as lgb
from sklearn.model_selection import GroupKFold
import pickle

import glob

import gc

# %%
OUTPUT_DIR = '/content/drive/MyDrive/kaggle/2022/OTTO/input/cris_baseline/output/'

# %% [markdown]
# # load & save

# %%
CFG.types = 'clicks'

with open(OUTPUT_DIR+f'{CFG.VER}_{CFG.types}_preds.pkl','rb') as f:
  clicks_pred_df = pickle.load(f)

# %%
CFG.types = 'carts'

with open(OUTPUT_DIR+f'{CFG.VER}_{CFG.types}_preds.pkl','rb') as f:
  carts_pred_df = pickle.load(f)

# %%
CFG.types = 'orders'

with open(OUTPUT_DIR+f'{CFG.VER}_{CFG.types}_preds.pkl','rb') as f:
  orders_pred_df = pickle.load(f)

# %%
pred_df = pd.concat([clicks_pred_df, carts_pred_df, orders_pred_df])
#pred_df.columns = ["session_type", "labels"]
#pred_df["labels"] = pred_df.labels.apply(lambda x: " ".join(map(str,x)))
pred_df.to_csv(OUTPUT_DIR + f"submission_{CFG.VER}.csv", index=False)
pred_df.head()
# Out:
#       session_type                                             labels
# 0  12899779_clicks  731692 25820 1790770 941596 59625 426813 11083...
# 1  12899780_clicks  618310 258814 1263108 1383529 1586171 1360606 ...
# 2  12899781_clicks  1460571 754412 331708 811084 918667 1681537 75...
# 3  12899782_clicks  1696036 562753 1711180 127404 834354 779477 13...
# 4  12899783_clicks  1586171 354698 294573 198385 1729553 84297 169...
